# %% [markdown]
# # L6: Building Your Crew for Production

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note <code>(Kernel Starting)</code>:</b> This notebook takes about 30 seconds to be ready to use. You may start and watch the video while you wait.</p>

# %% [markdown]
# ## Initial Imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
from helper import load_env
load_env()

# %% [markdown]
# <p style="background-color:#fff6ff; padding:15px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px"> 💻 &nbsp; <b>Access <code>requirements.txt</code> and <code>helper.py</code> files:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>. For more help, please see the <em>"Appendix - Tips and Help"</em> Lesson.</p>

# %% [markdown]
# ## Creating a new project

# %%
! crewai create crew new_project --provider openai
# Out:
# Creating folder new_project...
#   - Created new_project/.gitignore
#   - Created new_project/pyproject.toml
#   - Created new_project/README.md
#   - Created new_project/src/new_project/__init__.py
#   - Created new_project/src/new_project/main.py
#   - Created new_project/src/new_project/crew.py
#   - Created new_project/src/new_project/tools/custom_tool.py
#   - Created new_project/src/new_project/tools/__init__.py
#   - Created new_project/src/new_project/config/agents.yaml
#   - Created new_project/src/new_project/config/tasks.yaml
# Crew new_project created successfully!

# %% [markdown]
# ## Setting up the Environment

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note</code>:</b> The following line might take a few minutes to finish.</p>

# %%
! cd new_project && crewai install
# Out:
# Using CPython 3.11.9 interpreter at: /usr/local/bin/python
# Creating virtual environment at: .venv
# Resolved 228 packages in 1.54s
# Building new-project @ file:///home/jovyan/work/L13/new_project
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/223)
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/223)
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/223)
# pygments   ------------------------------     0 B/1.15 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/223)
# crewai-tools ------------------------------     0 B/452.13 KiB
# pygments   ------------------------------     0 B/1.15 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/223)
# crewai-tools ------------------------------     0 B/452.13 KiB
# langchain  ------------------------------     0 B/984.77 KiB
# pygments   ------------------------------     0 B/1.15 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/223)
# crewai-tools ------------------------------     0 B/452.13 KiB
# ipython    ------------------------------     0 B/800.69 KiB
# langchain  ------------------------------     0 B/984.77 KiB
# pygments   ------------------------------     0 B/1.15 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/223)
# crewai-tools ------------------------------     0 B/452.13 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# ipython    ------------------------------     0 B/800.69 KiB
# langchain  ------------------------------     0 B/984.77 KiB
# pygments   ------------------------------     0 B/1.15 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/223)
# crewai-tools ------------------------------     0 B/452.13 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# regex      ------------------------------     0 B/774.15 KiB
# ipython    ------------------------------     0 B/800.69 KiB
# langchain  ------------------------------     0 B/984.77 KiB
# pygments   ------------------------------     0 B/1.15 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/223)
# crewai-tools ------------------------------     0 B/452.13 KiB
# greenlet   ------------------------------     0 B/588.29 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# regex      ------------------------------     0 B/774.15 KiB
# ipython    ------------------------------     0 B/800.69 KiB
# langchain  ------------------------------     0 B/984.77 KiB
# pygments   ------------------------------     0 B/1.15 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/223)
# crewai-tools ------------------------------     0 B/452.13 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/588.29 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# regex      ------------------------------     0 B/774.15 KiB
# ipython    ------------------------------     0 B/800.69 KiB
# langchain  ------------------------------     0 B/984.77 KiB
# pygments   ------------------------------     0 B/1.15 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/223)
# crewai-tools ------------------------------     0 B/452.13 KiB
# pytz       ------------------------------     0 B/496.10 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/588.29 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# regex      ------------------------------     0 B/774.15 KiB
# ipython    ------------------------------     0 B/800.69 KiB
# langchain  ------------------------------     0 B/984.77 KiB
# pygments   ------------------------------     0 B/1.15 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/223)
# crewai-tools ------------------------------     0 B/452.13 KiB
# trio       ------------------------------     0 B/470.44 KiB
# pytz       ------------------------------     0 B/496.10 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/588.29 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# regex      ------------------------------     0 B/774.15 KiB
# ipython    ------------------------------     0 B/800.69 KiB
# langchain  ------------------------------     0 B/984.77 KiB
# pygments   ------------------------------     0 B/1.15 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/223)
# crewai-tools ------------------------------     0 B/452.13 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# trio       ------------------------------     0 B/470.44 KiB
# pytz       ------------------------------     0 B/496.10 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/588.29 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# regex      ------------------------------     0 B/774.15 KiB
# ipython    ------------------------------     0 B/800.69 KiB
# langchain  ------------------------------     0 B/984.77 KiB
# pygments   ------------------------------     0 B/1.15 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/223)
# httptools  ------------------------------     0 B/449.01 KiB
# crewai-tools ------------------------------     0 B/452.13 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# trio       ------------------------------     0 B/470.44 KiB
# pytz       ------------------------------     0 B/496.10 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/588.29 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# regex      ------------------------------     0 B/774.15 KiB
# ipython    ------------------------------     0 B/800.69 KiB
# langchain  ------------------------------     0 B/984.77 KiB
# pygments   ------------------------------     0 B/1.15 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/223)
# pydantic   ------------------------------     0 B/445.67 KiB
# httptools  ------------------------------     0 B/449.01 KiB
# crewai-tools ------------------------------     0 B/452.13 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# trio       ------------------------------     0 B/470.44 KiB
# pytz       ------------------------------     0 B/496.10 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/588.29 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# regex      ------------------------------     0 B/774.15 KiB
# ipython    ------------------------------     0 B/800.69 KiB
# langchain  ------------------------------     0 B/984.77 KiB
# pygments   ------------------------------     0 B/1.15 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/223)
# huggingface-hub ------------------------------     0 B/437.08 KiB
# pydantic   ------------------------------     0 B/445.67 KiB
# httptools  ------------------------------     0 B/449.01 KiB
# crewai-tools ------------------------------     0 B/452.13 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# trio       ------------------------------     0 B/470.44 KiB
# pytz       ------------------------------     0 B/496.10 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/588.29 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# regex      ------------------------------     0 B/774.15 KiB
# ipython    ------------------------------     0 B/800.69 KiB
# langchain  ------------------------------     0 B/984.77 KiB
# pygments   ------------------------------     0 B/1.15 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/223)
# prompt-toolkit ------------------------------ 30.88 KiB/377.53 KiB
# openai     ------------------------------ 30.82 KiB/380.43 KiB
# langchain-core ------------------------------ 14.91 KiB/399.87 KiB
# watchfiles ------------------------------ 14.92 KiB/432.19 KiB
# huggingface-hub ------------------------------ 46.91 KiB/437.08 KiB
# pydantic   ------------------------------ 30.89 KiB/445.67 KiB
# httptools  ------------------------------ 62.91 KiB/449.01 KiB
# crewai-tools ------------------------------ 30.91 KiB/452.13 KiB
# cffi       ------------------------------ 62.88 KiB/456.29 KiB
# trio       ------------------------------ 41.01 KiB/470.44 KiB
# pytz       ------------------------------ 30.88 KiB/496.10 KiB
# mpmath     ------------------------------ 30.84 KiB/523.63 KiB
# greenlet   ------------------------------ 30.91 KiB/588.29 KiB
# chromadb   ------------------------------ 30.92 KiB/603.40 KiB
# pyvis      ------------------------------ 14.84 KiB/738.32 KiB
# pyyaml     ------------------------------ 30.88 KiB/745.07 KiB
# regex      ------------------------------ 76.03 KiB/774.15 KiB
# ipython    ------------------------------ 62.88 KiB/800.69 KiB
# langchain  ------------------------------ 30.92 KiB/984.77 KiB
# tiktoken   ------------------------------ 14.91 KiB/1.03 MiB
# pygments   ------------------------------ 32.20 KiB/1.15 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/223)
# prompt-toolkit ------------------------------ 62.88 KiB/377.53 KiB
# openai     ------------------------------ 46.82 KiB/380.43 KiB
# langchain-core ------------------------------ 46.91 KiB/399.87 KiB
# watchfiles ------------------------------ 190.92 KiB/432.19 KiB
# huggingface-hub ------------------------------ 62.91 KiB/437.08 KiB
# pydantic   ------------------------------ 62.89 KiB/445.67 KiB
# httptools  ------------------------------ 190.91 KiB/449.01 KiB
# crewai-tools ------------------------------ 30.91 KiB/452.13 KiB
# cffi       ------------------------------ 190.80 KiB/456.29 KiB
# trio       ------------------------------ 77.50 KiB/470.44 KiB
# pytz       ------------------------------ 46.88 KiB/496.10 KiB
# mpmath     ------------------------------ 139.23 KiB/523.63 KiB
# greenlet   ------------------------------ 46.91 KiB/588.29 KiB
# chromadb   ------------------------------ 62.81 KiB/603.40 KiB
# pyvis      ------------------------------ 168.57 KiB/738.32 KiB
# pyyaml     ------------------------------ 175.16 KiB/745.07 KiB
# regex      ------------------------------ 172.03 KiB/774.15 KiB
# ipython    ------------------------------ 109.81 KiB/800.69 KiB
# langchain  ------------------------------ 30.92 KiB/984.77 KiB
# tiktoken   ------------------------------ 190.91 KiB/1.03 MiB
# pygments   ------------------------------ 64.20 KiB/1.15 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/223)
# prompt-toolkit ------------------------------ 91.42 KiB/377.53 KiB
# openai     ------------------------------ 67.17 KiB/380.43 KiB
# langchain-core ------------------------------ 62.91 KiB/399.87 KiB
# watchfiles ------------------------------ 270.92 KiB/432.19 KiB
# huggingface-hub ------------------------------ 236.00 KiB/437.08 KiB
# pydantic   ------------------------------ 157.05 KiB/445.67 KiB
# httptools  ------------------------------ 254.92 KiB/449.01 KiB
# crewai-tools ------------------------------ 46.81 KiB/452.13 KiB
# cffi       ------------------------------ 269.11 KiB/456.29 KiB
# trio       ------------------------------ 141.50 KiB/470.44 KiB
# pytz       ------------------------------ 46.88 KiB/496.10 KiB
# mpmath     ------------------------------ 235.23 KiB/523.63 KiB
# greenlet   ------------------------------ 254.85 KiB/588.29 KiB
# chromadb   ------------------------------ 78.81 KiB/603.40 KiB
# pyvis      ------------------------------ 216.68 KiB/738.32 KiB
# pyyaml     ------------------------------ 254.52 KiB/745.07 KiB
# regex      ------------------------------ 268.03 KiB/774.15 KiB
# ipython    ------------------------------ 200.07 KiB/800.69 KiB
# langchain  ------------------------------ 30.92 KiB/984.77 KiB
# tiktoken   ------------------------------ 270.91 KiB/1.03 MiB
# pygments   ------------------------------ 107.31 KiB/1.15 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/223)
# prompt-toolkit ------------------------------ 107.42 KiB/377.53 KiB
# openai     ------------------------------ 67.17 KiB/380.43 KiB
# langchain-core ------------------------------ 78.91 KiB/399.87 KiB
# watchfiles ------------------------------ 339.61 KiB/432.19 KiB
# huggingface-hub ------------------------------ 252.00 KiB/437.08 KiB
# pydantic   ------------------------------ 189.05 KiB/445.67 KiB
# httptools  ------------------------------ 330.69 KiB/449.01 KiB
# crewai-tools ------------------------------ 196.19 KiB/452.13 KiB
# cffi       ------------------------------ 334.80 KiB/456.29 KiB
# trio       ------------------------------ 173.50 KiB/470.44 KiB
# pytz       ------------------------------ 62.88 KiB/496.10 KiB
# mpmath     ------------------------------ 303.23 KiB/523.63 KiB
# greenlet   ------------------------------ 334.85 KiB/588.29 KiB
# chromadb   ------------------------------ 110.92 KiB/603.40 KiB
# pyvis      ------------------------------ 280.58 KiB/738.32 KiB
# pyyaml     ------------------------------ 334.52 KiB/745.07 KiB
# regex      ------------------------------ 348.03 KiB/774.15 KiB
# ipython    ------------------------------ 260.09 KiB/800.69 KiB
# langchain  ------------------------------ 46.92 KiB/984.77 KiB
# tiktoken   ------------------------------ 334.91 KiB/1.03 MiB
# pygments   ------------------------------ 251.21 KiB/1.15 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/223)
# prompt-toolkit ------------------------------ 123.42 KiB/377.53 KiB
# openai     ------------------------------ 77.55 KiB/380.43 KiB
# langchain-core ------------------------------ 118.82 KiB/399.87 KiB
# watchfiles ------------------------------ 404.07 KiB/432.19 KiB
# huggingface-hub ------------------------------ 332.00 KiB/437.08 KiB
# pydantic   ------------------------------ 269.05 KiB/445.67 KiB
# httptools  ------------------------------ 398.81 KiB/449.01 KiB
# crewai-tools ------------------------------ 357.10 KiB/452.13 KiB
# cffi       ------------------------------ 414.80 KiB/456.29 KiB
# trio       ------------------------------ 253.50 KiB/470.44 KiB
# pytz       ------------------------------ 110.81 KiB/496.10 KiB
# mpmath     ------------------------------ 383.13 KiB/523.63 KiB
# greenlet   ------------------------------ 398.85 KiB/588.29 KiB
# chromadb   ------------------------------ 366.92 KiB/603.40 KiB
# pyvis      ------------------------------ 344.58 KiB/738.32 KiB
# pyyaml     ------------------------------ 411.24 KiB/745.07 KiB
# regex      ------------------------------ 428.03 KiB/774.15 KiB
# ipython    ------------------------------ 333.81 KiB/800.69 KiB
# langchain  ------------------------------ 46.92 KiB/984.77 KiB
# tiktoken   ------------------------------ 408.56 KiB/1.03 MiB
# pygments   ------------------------------ 335.31 KiB/1.15 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/223)
# prompt-toolkit ------------------------------ 139.42 KiB/377.53 KiB
# openai     ------------------------------ 109.45 KiB/380.43 KiB
# langchain-core ------------------------------ 134.72 KiB/399.87 KiB
# huggingface-hub ------------------------------ 332.00 KiB/437.08 KiB
# pydantic   ------------------------------ 281.99 KiB/445.67 KiB
# httptools  ------------------------------ 430.91 KiB/449.01 KiB
# crewai-tools ------------------------------ 398.43 KiB/452.13 KiB
# cffi       ------------------------------ 446.80 KiB/456.29 KiB
# trio       ------------------------------ 285.50 KiB/470.44 KiB
# pytz       ------------------------------ 110.81 KiB/496.10 KiB
# mpmath     ------------------------------ 415.23 KiB/523.63 KiB
# greenlet   ------------------------------ 444.70 KiB/588.29 KiB
# chromadb   ------------------------------ 366.92 KiB/603.40 KiB
# pyvis      ------------------------------ 408.58 KiB/738.32 KiB
# pyyaml     ------------------------------ 459.24 KiB/745.07 KiB
# regex      ------------------------------ 476.03 KiB/774.15 KiB
# ipython    ------------------------------ 349.81 KiB/800.69 KiB
# langchain  ------------------------------ 46.92 KiB/984.77 KiB
# tiktoken   ------------------------------ 451.52 KiB/1.03 MiB
# pygments   ------------------------------ 367.31 KiB/1.15 MiB
# jedi       ------------------------------ 202.14 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/223)
# rpds-py    ------------------------------     0 B/351.99 KiB
# prompt-toolkit ------------------------------ 139.42 KiB/377.53 KiB
# openai     ------------------------------ 109.45 KiB/380.43 KiB
# langchain-core ------------------------------ 142.91 KiB/399.87 KiB
# huggingface-hub ------------------------------ 348.00 KiB/437.08 KiB
# pydantic   ------------------------------ 297.99 KiB/445.67 KiB
# crewai-tools ------------------------------ 414.91 KiB/452.13 KiB
# cffi       ------------------------------ 456.29 KiB/456.29 KiB
# trio       ------------------------------ 301.50 KiB/470.44 KiB
# pytz       ------------------------------ 110.81 KiB/496.10 KiB
# mpmath     ------------------------------ 415.23 KiB/523.63 KiB
# greenlet   ------------------------------ 478.85 KiB/588.29 KiB
# chromadb   ------------------------------ 382.92 KiB/603.40 KiB
# pyvis      ------------------------------ 424.58 KiB/738.32 KiB
# pyyaml     ------------------------------ 478.52 KiB/745.07 KiB
# regex      ------------------------------ 508.03 KiB/774.15 KiB
# ipython    ------------------------------ 349.81 KiB/800.69 KiB
# langchain  ------------------------------ 46.92 KiB/984.77 KiB
# tiktoken   ------------------------------ 472.56 KiB/1.03 MiB
# pygments   ------------------------------ 399.31 KiB/1.15 MiB
# jedi       ------------------------------ 218.14 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/223)
# rpds-py    ------------------------------     0 B/351.99 KiB
# prompt-toolkit ------------------------------ 139.42 KiB/377.53 KiB
# openai     ------------------------------ 125.45 KiB/380.43 KiB
# langchain-core ------------------------------ 158.91 KiB/399.87 KiB
# huggingface-hub ------------------------------ 348.00 KiB/437.08 KiB
# pydantic   ------------------------------ 297.99 KiB/445.67 KiB
# crewai-tools ------------------------------ 414.91 KiB/452.13 KiB
# trio       ------------------------------ 301.50 KiB/470.44 KiB
# pytz       ------------------------------ 110.81 KiB/496.10 KiB
# mpmath     ------------------------------ 431.23 KiB/523.63 KiB
# greenlet   ------------------------------ 478.85 KiB/588.29 KiB
# chromadb   ------------------------------ 382.92 KiB/603.40 KiB
# pyvis      ------------------------------ 440.58 KiB/738.32 KiB
# pyyaml     ------------------------------ 489.72 KiB/745.07 KiB
# regex      ------------------------------ 524.03 KiB/774.15 KiB
# ipython    ------------------------------ 365.81 KiB/800.69 KiB
# langchain  ------------------------------ 46.92 KiB/984.77 KiB
# tiktoken   ------------------------------ 488.56 KiB/1.03 MiB
# pygments   ------------------------------ 399.31 KiB/1.15 MiB
# jedi       ------------------------------ 218.14 KiB/1.50 MiB
# aiohttp    ------------------------------ 428.98 KiB/1.60 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/223)
# rpds-py    ------------------------------ 16.00 KiB/351.99 KiB
# prompt-toolkit ------------------------------ 155.42 KiB/377.53 KiB
# openai     ------------------------------ 125.45 KiB/380.43 KiB
# langchain-core ------------------------------ 158.91 KiB/399.87 KiB
# huggingface-hub ------------------------------ 348.00 KiB/437.08 KiB
# pydantic   ------------------------------ 297.99 KiB/445.67 KiB
# crewai-tools ------------------------------ 414.91 KiB/452.13 KiB
# trio       ------------------------------ 301.50 KiB/470.44 KiB
# pytz       ------------------------------ 110.81 KiB/496.10 KiB
# mpmath     ------------------------------ 439.86 KiB/523.63 KiB
# greenlet   ------------------------------ 494.85 KiB/588.29 KiB
# chromadb   ------------------------------ 382.92 KiB/603.40 KiB
# pyvis      ------------------------------ 451.48 KiB/738.32 KiB
# pyyaml     ------------------------------ 489.72 KiB/745.07 KiB
# regex      ------------------------------ 524.03 KiB/774.15 KiB
# ipython    ------------------------------ 365.81 KiB/800.69 KiB
# langchain  ------------------------------ 46.92 KiB/984.77 KiB
# tiktoken   ------------------------------ 488.56 KiB/1.03 MiB
# pygments   ------------------------------ 399.31 KiB/1.15 MiB
# jedi       ------------------------------ 234.14 KiB/1.50 MiB
# aiohttp    ------------------------------ 444.98 KiB/1.60 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/223)
# tzdata     ------------------------------ 16.00 KiB/338.46 KiB
# google-cloud-resource-manager ------------------------------ 47.89 KiB/350.17 KiB
# rpds-py    ------------------------------ 97.13 KiB/351.99 KiB
# prompt-toolkit ------------------------------ 203.32 KiB/377.53 KiB
# openai     ------------------------------ 173.45 KiB/380.43 KiB
# langchain-core ------------------------------ 190.91 KiB/399.87 KiB
# huggingface-hub ------------------------------ 396.00 KiB/437.08 KiB
# pydantic   ------------------------------ 445.05 KiB/445.67 KiB
# crewai-tools ------------------------------ 430.91 KiB/452.13 KiB
# trio       ------------------------------ 349.50 KiB/470.44 KiB
# pytz       ------------------------------ 126.81 KiB/496.10 KiB
# mpmath     ------------------------------ 511.23 KiB/523.63 KiB
# greenlet   ------------------------------ 542.85 KiB/588.29 KiB
# chromadb   ------------------------------ 414.92 KiB/603.40 KiB
# pyvis      ------------------------------ 520.58 KiB/738.32 KiB
# pyyaml     ------------------------------ 566.45 KiB/745.07 KiB
# regex      ------------------------------ 620.03 KiB/774.15 KiB
# ipython    ------------------------------ 429.81 KiB/800.69 KiB
# langchain  ------------------------------ 62.92 KiB/984.77 KiB
# tiktoken   ------------------------------ 584.56 KiB/1.03 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/223)
# tzdata     ------------------------------ 16.00 KiB/338.46 KiB
# google-cloud-resource-manager ------------------------------ 63.89 KiB/350.17 KiB
# rpds-py    ------------------------------ 113.13 KiB/351.99 KiB
# prompt-toolkit ------------------------------ 219.42 KiB/377.53 KiB
# openai     ------------------------------ 189.45 KiB/380.43 KiB
# langchain-core ------------------------------ 238.81 KiB/399.87 KiB
# huggingface-hub ------------------------------ 412.00 KiB/437.08 KiB
# crewai-tools ------------------------------ 430.91 KiB/452.13 KiB
# trio       ------------------------------ 381.50 KiB/470.44 KiB
# pytz       ------------------------------ 126.81 KiB/496.10 KiB
# mpmath     ------------------------------ 511.23 KiB/523.63 KiB
# greenlet   ------------------------------ 558.85 KiB/588.29 KiB
# chromadb   ------------------------------ 414.92 KiB/603.40 KiB
# pyvis      ------------------------------ 536.58 KiB/738.32 KiB
# pyyaml     ------------------------------ 582.45 KiB/745.07 KiB
# regex      ------------------------------ 636.03 KiB/774.15 KiB
# ipython    ------------------------------ 445.81 KiB/800.69 KiB
# langchain  ------------------------------ 78.92 KiB/984.77 KiB
# tiktoken   ------------------------------ 599.56 KiB/1.03 MiB
# pygments   ------------------------------ 511.31 KiB/1.15 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/223)
# yarl       ------------------------------     0 B/335.82 KiB
# tzdata     ------------------------------ 16.00 KiB/338.46 KiB
# google-cloud-resource-manager ------------------------------ 96.00 KiB/350.17 KiB
# rpds-py    ------------------------------ 141.03 KiB/351.99 KiB
# prompt-toolkit ------------------------------ 267.42 KiB/377.53 KiB
# openai     ------------------------------ 205.45 KiB/380.43 KiB
# langchain-core ------------------------------ 270.81 KiB/399.87 KiB
# huggingface-hub ------------------------------ 428.00 KiB/437.08 KiB
# crewai-tools ------------------------------ 446.91 KiB/452.13 KiB
# trio       ------------------------------ 413.50 KiB/470.44 KiB
# pytz       ------------------------------ 126.81 KiB/496.10 KiB
# greenlet   ------------------------------ 558.85 KiB/588.29 KiB
# chromadb   ------------------------------ 430.81 KiB/603.40 KiB
# pyvis      ------------------------------ 568.47 KiB/738.32 KiB
# pyyaml     ------------------------------ 606.52 KiB/745.07 KiB
# regex      ------------------------------ 668.03 KiB/774.15 KiB
# ipython    ------------------------------ 461.81 KiB/800.69 KiB
# langchain  ------------------------------ 78.92 KiB/984.77 KiB
# tiktoken   ------------------------------ 622.65 KiB/1.03 MiB
# pygments   ------------------------------ 527.31 KiB/1.15 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/223)
# yarl       ------------------------------ 4.01 KiB/335.82 KiB
# tzdata     ------------------------------ 32.00 KiB/338.46 KiB
# google-cloud-resource-manager ------------------------------ 128.00 KiB/350.17 KiB
# rpds-py    ------------------------------ 157.03 KiB/351.99 KiB
# prompt-toolkit ------------------------------ 287.42 KiB/377.53 KiB
# openai     ------------------------------ 205.45 KiB/380.43 KiB
# langchain-core ------------------------------ 283.28 KiB/399.87 KiB
# crewai-tools ------------------------------ 446.91 KiB/452.13 KiB
# trio       ------------------------------ 413.50 KiB/470.44 KiB
# pytz       ------------------------------ 126.81 KiB/496.10 KiB
# greenlet   ------------------------------ 574.85 KiB/588.29 KiB
# chromadb   ------------------------------ 446.81 KiB/603.40 KiB
# pyvis      ------------------------------ 584.58 KiB/738.32 KiB
# pyyaml     ------------------------------ 622.52 KiB/745.07 KiB
# regex      ------------------------------ 677.36 KiB/774.15 KiB
# ipython    ------------------------------ 477.81 KiB/800.69 KiB
# langchain  ------------------------------ 78.92 KiB/984.77 KiB
# tiktoken   ------------------------------ 648.56 KiB/1.03 MiB
# pygments   ------------------------------ 538.63 KiB/1.15 MiB
# jedi       ------------------------------ 248.64 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/223)
# pytest     ------------------------------     0 B/334.32 KiB
# yarl       ------------------------------ 20.01 KiB/335.82 KiB
# tzdata     ------------------------------ 32.00 KiB/338.46 KiB
# google-cloud-resource-manager ------------------------------ 128.00 KiB/350.17 KiB
# rpds-py    ------------------------------ 173.03 KiB/351.99 KiB
# prompt-toolkit ------------------------------ 287.42 KiB/377.53 KiB
# openai     ------------------------------ 205.45 KiB/380.43 KiB
# langchain-core ------------------------------ 283.28 KiB/399.87 KiB
# trio       ------------------------------ 413.50 KiB/470.44 KiB
# pytz       ------------------------------ 126.81 KiB/496.10 KiB
# greenlet   ------------------------------ 574.85 KiB/588.29 KiB
# chromadb   ------------------------------ 446.81 KiB/603.40 KiB
# pyvis      ------------------------------ 584.58 KiB/738.32 KiB
# pyyaml     ------------------------------ 638.52 KiB/745.07 KiB
# regex      ------------------------------ 688.89 KiB/774.15 KiB
# ipython    ------------------------------ 477.81 KiB/800.69 KiB
# langchain  ------------------------------ 94.92 KiB/984.77 KiB
# tiktoken   ------------------------------ 648.56 KiB/1.03 MiB
# pygments   ------------------------------ 543.31 KiB/1.15 MiB
# jedi       ------------------------------ 248.64 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/223)
# protobuf   ------------------------------     0 B/312.18 KiB
# jiter      ------------------------------     0 B/317.86 KiB
# pytest     ------------------------------ 14.88 KiB/334.32 KiB
# yarl       ------------------------------ 36.01 KiB/335.82 KiB
# tzdata     ------------------------------ 32.00 KiB/338.46 KiB
# google-cloud-resource-manager ------------------------------ 155.67 KiB/350.17 KiB
# rpds-py    ------------------------------ 189.03 KiB/351.99 KiB
# prompt-toolkit ------------------------------ 287.42 KiB/377.53 KiB
# openai     ------------------------------ 205.45 KiB/380.43 KiB
# langchain-core ------------------------------ 299.28 KiB/399.87 KiB
# trio       ------------------------------ 429.50 KiB/470.44 KiB
# pytz       ------------------------------ 126.81 KiB/496.10 KiB
# greenlet   ------------------------------ 574.85 KiB/588.29 KiB
# chromadb   ------------------------------ 446.81 KiB/603.40 KiB
# pyvis      ------------------------------ 600.47 KiB/738.32 KiB
# pyyaml     ------------------------------ 654.52 KiB/745.07 KiB
# regex      ------------------------------ 704.89 KiB/774.15 KiB
# ipython    ------------------------------ 477.81 KiB/800.69 KiB
# langchain  ------------------------------ 94.92 KiB/984.77 KiB
# tiktoken   ------------------------------ 664.56 KiB/1.03 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (7/223)
# protobuf   ------------------------------ 48.00 KiB/312.18 KiB
# jiter      ------------------------------ 34.95 KiB/317.86 KiB
# pytest     ------------------------------ 62.88 KiB/334.32 KiB
# yarl       ------------------------------ 79.05 KiB/335.82 KiB
# tzdata     ------------------------------ 79.73 KiB/338.46 KiB
# google-cloud-resource-manager ------------------------------ 192.00 KiB/350.17 KiB
# rpds-py    ------------------------------ 223.17 KiB/351.99 KiB
# prompt-toolkit ------------------------------ 335.42 KiB/377.53 KiB
# openai     ------------------------------ 221.55 KiB/380.43 KiB
# langchain-core ------------------------------ 327.06 KiB/399.87 KiB
# trio       ------------------------------ 461.50 KiB/470.44 KiB
# pytz       ------------------------------ 142.81 KiB/496.10 KiB
# chromadb   ------------------------------ 478.92 KiB/603.40 KiB
# pyvis      ------------------------------ 648.58 KiB/738.32 KiB
# pyyaml     ------------------------------ 702.52 KiB/745.07 KiB
# regex      ------------------------------ 748.03 KiB/774.15 KiB
# ipython    ------------------------------ 573.81 KiB/800.69 KiB
# langchain  ------------------------------ 110.92 KiB/984.77 KiB
# tiktoken   ------------------------------ 712.56 KiB/1.03 MiB
# pygments   ------------------------------ 623.31 KiB/1.15 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (7/223)
# protobuf   ------------------------------ 61.75 KiB/312.18 KiB
# jiter      ------------------------------ 50.95 KiB/317.86 KiB
# pytest     ------------------------------ 76.65 KiB/334.32 KiB
# yarl       ------------------------------ 79.05 KiB/335.82 KiB
# tzdata     ------------------------------ 79.73 KiB/338.46 KiB
# google-cloud-resource-manager ------------------------------ 208.00 KiB/350.17 KiB
# rpds-py    ------------------------------ 239.17 KiB/351.99 KiB
# prompt-toolkit ------------------------------ 351.42 KiB/377.53 KiB
# openai     ------------------------------ 221.55 KiB/380.43 KiB
# langchain-core ------------------------------ 334.91 KiB/399.87 KiB
# pytz       ------------------------------ 142.81 KiB/496.10 KiB
# chromadb   ------------------------------ 478.92 KiB/603.40 KiB
# pyvis      ------------------------------ 648.58 KiB/738.32 KiB
# pyyaml     ------------------------------ 718.52 KiB/745.07 KiB
# regex      ------------------------------ 764.03 KiB/774.15 KiB
# ipython    ------------------------------ 573.81 KiB/800.69 KiB
# langchain  ------------------------------ 110.92 KiB/984.77 KiB
# tiktoken   ------------------------------ 712.56 KiB/1.03 MiB
# pygments   ------------------------------ 639.31 KiB/1.15 MiB
# jedi       ------------------------------ 268.56 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (7/223)
# langsmith  ------------------------------     0 B/304.50 KiB
# protobuf   ------------------------------ 77.75 KiB/312.18 KiB
# jiter      ------------------------------ 55.10 KiB/317.86 KiB
# pytest     ------------------------------ 92.65 KiB/334.32 KiB
# yarl       ------------------------------ 95.05 KiB/335.82 KiB
# tzdata     ------------------------------ 79.73 KiB/338.46 KiB
# google-cloud-resource-manager ------------------------------ 223.89 KiB/350.17 KiB
# rpds-py    ------------------------------ 255.17 KiB/351.99 KiB
# prompt-toolkit ------------------------------ 367.42 KiB/377.53 KiB
# openai     ------------------------------ 221.55 KiB/380.43 KiB
# langchain-core ------------------------------ 350.91 KiB/399.87 KiB
# pytz       ------------------------------ 142.81 KiB/496.10 KiB
# chromadb   ------------------------------ 478.92 KiB/603.40 KiB
# pyvis      ------------------------------ 664.58 KiB/738.32 KiB
# pyyaml     ------------------------------ 734.52 KiB/745.07 KiB
# ipython    ------------------------------ 573.81 KiB/800.69 KiB
# langchain  ------------------------------ 126.92 KiB/984.77 KiB
# tiktoken   ------------------------------ 728.56 KiB/1.03 MiB
# pygments   ------------------------------ 655.31 KiB/1.15 MiB
# jedi       ------------------------------ 268.56 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (7/223)
# pypdf      ------------------------------     0 B/290.99 KiB
# langsmith  ------------------------------     0 B/304.50 KiB
# protobuf   ------------------------------ 77.75 KiB/312.18 KiB
# jiter      ------------------------------ 55.10 KiB/317.86 KiB
# pytest     ------------------------------ 92.65 KiB/334.32 KiB
# yarl       ------------------------------ 111.05 KiB/335.82 KiB
# tzdata     ------------------------------ 79.73 KiB/338.46 KiB
# google-cloud-resource-manager ------------------------------ 223.89 KiB/350.17 KiB
# rpds-py    ------------------------------ 255.17 KiB/351.99 KiB
# prompt-toolkit ------------------------------ 367.42 KiB/377.53 KiB
# openai     ------------------------------ 221.55 KiB/380.43 KiB
# langchain-core ------------------------------ 350.91 KiB/399.87 KiB
# pytz       ------------------------------ 142.81 KiB/496.10 KiB
# chromadb   ------------------------------ 478.92 KiB/603.40 KiB
# pyvis      ------------------------------ 680.58 KiB/738.32 KiB
# pyyaml     ------------------------------ 734.52 KiB/745.07 KiB
# ipython    ------------------------------ 573.81 KiB/800.69 KiB
# langchain  ------------------------------ 126.92 KiB/984.77 KiB
# tiktoken   ------------------------------ 744.56 KiB/1.03 MiB
# pygments   ------------------------------ 655.31 KiB/1.15 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (7/223)
# bcrypt     ------------------------------     0 B/272.08 KiB
# pypdf      ------------------------------ 14.92 KiB/290.99 KiB
# langsmith  ------------------------------ 16.00 KiB/304.50 KiB
# protobuf   ------------------------------ 93.64 KiB/312.18 KiB
# jiter      ------------------------------ 71.10 KiB/317.86 KiB
# pytest     ------------------------------ 108.65 KiB/334.32 KiB
# yarl       ------------------------------ 127.05 KiB/335.82 KiB
# tzdata     ------------------------------ 79.73 KiB/338.46 KiB
# google-cloud-resource-manager ------------------------------ 239.89 KiB/350.17 KiB
# rpds-py    ------------------------------ 271.17 KiB/351.99 KiB
# prompt-toolkit ------------------------------ 367.42 KiB/377.53 KiB
# openai     ------------------------------ 221.55 KiB/380.43 KiB
# langchain-core ------------------------------ 350.91 KiB/399.87 KiB
# pytz       ------------------------------ 158.81 KiB/496.10 KiB
# chromadb   ------------------------------ 478.92 KiB/603.40 KiB
# pyvis      ------------------------------ 696.58 KiB/738.32 KiB
# ipython    ------------------------------ 589.81 KiB/800.69 KiB
# langchain  ------------------------------ 126.92 KiB/984.77 KiB
# tiktoken   ------------------------------ 760.56 KiB/1.03 MiB
# pygments   ------------------------------ 671.31 KiB/1.15 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (7/223)
# bcrypt     ------------------------------     0 B/272.08 KiB
# pypdf      ------------------------------ 14.92 KiB/290.99 KiB
# langsmith  ------------------------------ 16.00 KiB/304.50 KiB
# protobuf   ------------------------------ 109.54 KiB/312.18 KiB
# jiter      ------------------------------ 87.10 KiB/317.86 KiB
# pytest     ------------------------------ 124.65 KiB/334.32 KiB
# yarl       ------------------------------ 127.05 KiB/335.82 KiB
# tzdata     ------------------------------ 79.73 KiB/338.46 KiB
# google-cloud-resource-manager ------------------------------ 255.89 KiB/350.17 KiB
# rpds-py    ------------------------------ 287.17 KiB/351.99 KiB
# openai     ------------------------------ 221.55 KiB/380.43 KiB
# langchain-core ------------------------------ 350.91 KiB/399.87 KiB
# pytz       ------------------------------ 158.81 KiB/496.10 KiB
# chromadb   ------------------------------ 478.92 KiB/603.40 KiB
# pyvis      ------------------------------ 696.58 KiB/738.32 KiB
# ipython    ------------------------------ 605.81 KiB/800.69 KiB
# langchain  ------------------------------ 126.92 KiB/984.77 KiB
# tiktoken   ------------------------------ 760.56 KiB/1.03 MiB
# pygments   ------------------------------ 687.31 KiB/1.15 MiB
# jedi       ------------------------------ 268.56 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (7/223)
# qdrant-client ------------------------------     0 B/260.91 KiB
# frozenlist ------------------------------ 16.00 KiB/268.43 KiB
# bcrypt     ------------------------------ 48.00 KiB/272.08 KiB
# pypdf      ------------------------------ 46.92 KiB/290.99 KiB
# langsmith  ------------------------------ 48.00 KiB/304.50 KiB
# protobuf   ------------------------------ 125.75 KiB/312.18 KiB
# jiter      ------------------------------ 114.95 KiB/317.86 KiB
# pytest     ------------------------------ 140.65 KiB/334.32 KiB
# yarl       ------------------------------ 159.05 KiB/335.82 KiB
# tzdata     ------------------------------ 79.73 KiB/338.46 KiB
# google-cloud-resource-manager ------------------------------ 272.00 KiB/350.17 KiB
# rpds-py    ------------------------------ 319.17 KiB/351.99 KiB
# openai     ------------------------------ 238.95 KiB/380.43 KiB
# pytz       ------------------------------ 158.81 KiB/496.10 KiB
# chromadb   ------------------------------ 494.81 KiB/603.40 KiB
# pyvis      ------------------------------ 738.32 KiB/738.32 KiB
# ipython    ------------------------------ 637.81 KiB/800.69 KiB
# langchain  ------------------------------ 126.92 KiB/984.77 KiB
# tiktoken   ------------------------------ 792.56 KiB/1.03 MiB
# pygments   ------------------------------ 760.24 KiB/1.15 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (7/223)
# openpyxl   ------------------------------     0 B/245.03 KiB
# qdrant-client ------------------------------ 32.00 KiB/260.91 KiB
# frozenlist ------------------------------ 48.00 KiB/268.43 KiB
# bcrypt     ------------------------------ 61.05 KiB/272.08 KiB
# pypdf      ------------------------------ 78.92 KiB/290.99 KiB
# langsmith  ------------------------------ 80.00 KiB/304.50 KiB
# protobuf   ------------------------------ 141.75 KiB/312.18 KiB
# jiter      ------------------------------ 130.95 KiB/317.86 KiB
# pytest     ------------------------------ 147.36 KiB/334.32 KiB
# yarl       ------------------------------ 191.05 KiB/335.82 KiB
# tzdata     ------------------------------ 95.73 KiB/338.46 KiB
# google-cloud-resource-manager ------------------------------ 295.48 KiB/350.17 KiB
# rpds-py    ------------------------------ 335.17 KiB/351.99 KiB
# openai     ------------------------------ 238.95 KiB/380.43 KiB
# pytz       ------------------------------ 165.71 KiB/496.10 KiB
# chromadb   ------------------------------ 494.81 KiB/603.40 KiB
# ipython    ------------------------------ 653.81 KiB/800.69 KiB
# langchain  ------------------------------ 142.92 KiB/984.77 KiB
# tiktoken   ------------------------------ 808.56 KiB/1.03 MiB
# pygments   ------------------------------ 776.24 KiB/1.15 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (7/223)
# openpyxl   ------------------------------     0 B/245.03 KiB
# qdrant-client ------------------------------ 32.00 KiB/260.91 KiB
# frozenlist ------------------------------ 48.00 KiB/268.43 KiB
# bcrypt     ------------------------------ 61.05 KiB/272.08 KiB
# pypdf      ------------------------------ 78.92 KiB/290.99 KiB
# langsmith  ------------------------------ 80.00 KiB/304.50 KiB
# protobuf   ------------------------------ 157.75 KiB/312.18 KiB
# jiter      ------------------------------ 146.85 KiB/317.86 KiB
# pytest     ------------------------------ 163.36 KiB/334.32 KiB
# yarl       ------------------------------ 191.05 KiB/335.82 KiB
# tzdata     ------------------------------ 95.73 KiB/338.46 KiB
# google-cloud-resource-manager ------------------------------ 295.48 KiB/350.17 KiB
# rpds-py    ------------------------------ 335.17 KiB/351.99 KiB
# openai     ------------------------------ 238.95 KiB/380.43 KiB
# pytz       ------------------------------ 165.71 KiB/496.10 KiB
# chromadb   ------------------------------ 494.81 KiB/603.40 KiB
# ipython    ------------------------------ 653.81 KiB/800.69 KiB
# langchain  ------------------------------ 142.92 KiB/984.77 KiB
# tiktoken   ------------------------------ 808.56 KiB/1.03 MiB
# pygments   ------------------------------ 792.24 KiB/1.15 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (7/223)
# cohere     ------------------------------ 14.92 KiB/243.80 KiB
# openpyxl   ------------------------------ 14.77 KiB/245.03 KiB
# qdrant-client ------------------------------ 47.89 KiB/260.91 KiB
# frozenlist ------------------------------ 64.83 KiB/268.43 KiB
# bcrypt     ------------------------------ 93.05 KiB/272.08 KiB
# pypdf      ------------------------------ 104.07 KiB/290.99 KiB
# langsmith  ------------------------------ 96.00 KiB/304.50 KiB
# protobuf   ------------------------------ 173.75 KiB/312.18 KiB
# jiter      ------------------------------ 162.85 KiB/317.86 KiB
# pytest     ------------------------------ 195.36 KiB/334.32 KiB
# yarl       ------------------------------ 207.05 KiB/335.82 KiB
# tzdata     ------------------------------ 95.73 KiB/338.46 KiB
# google-cloud-resource-manager ------------------------------ 320.00 KiB/350.17 KiB
# openai     ------------------------------ 238.95 KiB/380.43 KiB
# pytz       ------------------------------ 181.71 KiB/496.10 KiB
# chromadb   ------------------------------ 542.92 KiB/603.40 KiB
# ipython    ------------------------------ 653.81 KiB/800.69 KiB
# langchain  ------------------------------ 142.92 KiB/984.77 KiB
# tiktoken   ------------------------------ 840.56 KiB/1.03 MiB
# pygments   ------------------------------ 799.31 KiB/1.15 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (7/223)
# rich       ------------------------------     0 B/236.74 KiB
# cohere     ------------------------------ 31.53 KiB/243.80 KiB
# openpyxl   ------------------------------ 30.77 KiB/245.03 KiB
# qdrant-client ------------------------------ 80.00 KiB/260.91 KiB
# frozenlist ------------------------------ 87.76 KiB/268.43 KiB
# bcrypt     ------------------------------ 114.99 KiB/272.08 KiB
# pypdf      ------------------------------ 136.07 KiB/290.99 KiB
# langsmith  ------------------------------ 131.29 KiB/304.50 KiB
# protobuf   ------------------------------ 214.44 KiB/312.18 KiB
# jiter      ------------------------------ 194.95 KiB/317.86 KiB
# pytest     ------------------------------ 220.65 KiB/334.32 KiB
# yarl       ------------------------------ 255.05 KiB/335.82 KiB
# tzdata     ------------------------------ 95.73 KiB/338.46 KiB
# openai     ------------------------------ 254.95 KiB/380.43 KiB
# pytz       ------------------------------ 181.71 KiB/496.10 KiB
# chromadb   ------------------------------ 558.92 KiB/603.40 KiB
# ipython    ------------------------------ 685.81 KiB/800.69 KiB
# langchain  ------------------------------ 142.92 KiB/984.77 KiB
# tiktoken   ------------------------------ 872.56 KiB/1.03 MiB
# pygments   ------------------------------ 847.31 KiB/1.15 MiB
# jedi       ------------------------------ 284.56 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (7/223)
# google-cloud-bigquery ------------------------------     0 B/234.47 KiB
# rich       ------------------------------ 30.92 KiB/236.74 KiB
# cohere     ------------------------------ 47.53 KiB/243.80 KiB
# openpyxl   ------------------------------ 30.77 KiB/245.03 KiB
# qdrant-client ------------------------------ 96.00 KiB/260.91 KiB
# frozenlist ------------------------------ 119.76 KiB/268.43 KiB
# bcrypt     ------------------------------ 125.47 KiB/272.08 KiB
# pypdf      ------------------------------ 142.92 KiB/290.99 KiB
# langsmith  ------------------------------ 147.29 KiB/304.50 KiB
# protobuf   ------------------------------ 230.44 KiB/312.18 KiB
# jiter      ------------------------------ 226.95 KiB/317.86 KiB
# pytest     ------------------------------ 236.65 KiB/334.32 KiB
# yarl       ------------------------------ 271.05 KiB/335.82 KiB
# tzdata     ------------------------------ 95.73 KiB/338.46 KiB
# openai     ------------------------------ 254.95 KiB/380.43 KiB
# pytz       ------------------------------ 197.71 KiB/496.10 KiB
# chromadb   ------------------------------ 558.92 KiB/603.40 KiB
# ipython    ------------------------------ 685.81 KiB/800.69 KiB
# langchain  ------------------------------ 158.92 KiB/984.77 KiB
# tiktoken   ------------------------------ 904.56 KiB/1.03 MiB
# pygments   ------------------------------ 854.49 KiB/1.15 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (7/223)
# google-cloud-bigquery ------------------------------ 79.62 KiB/234.47 KiB
# rich       ------------------------------ 62.92 KiB/236.74 KiB
# cohere     ------------------------------ 78.92 KiB/243.80 KiB
# openpyxl   ------------------------------ 46.77 KiB/245.03 KiB
# qdrant-client ------------------------------ 160.00 KiB/260.91 KiB
# frozenlist ------------------------------ 173.87 KiB/268.43 KiB
# bcrypt     ------------------------------ 205.05 KiB/272.08 KiB
# pypdf      ------------------------------ 214.11 KiB/290.99 KiB
# langsmith  ------------------------------ 224.00 KiB/304.50 KiB
# protobuf   ------------------------------ 301.75 KiB/312.18 KiB
# jiter      ------------------------------ 290.95 KiB/317.86 KiB
# pytest     ------------------------------ 307.76 KiB/334.32 KiB
# yarl       ------------------------------ 319.05 KiB/335.82 KiB
# tzdata     ------------------------------ 113.58 KiB/338.46 KiB
# openai     ------------------------------ 268.33 KiB/380.43 KiB
# pytz       ------------------------------ 206.81 KiB/496.10 KiB
# chromadb   ------------------------------ 590.92 KiB/603.40 KiB
# ipython    ------------------------------ 717.81 KiB/800.69 KiB
# langchain  ------------------------------ 198.72 KiB/984.77 KiB
# tiktoken   ------------------------------ 963.56 KiB/1.03 MiB
# pygments   ------------------------------ 927.31 KiB/1.15 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠼ Preparing packages... (16/223)
# ...
# ⠇ Preparing packages... (218/223) 16.05 MiB/38.22 MiB
# pandas     ------------------------------ 9.67 MiB/12.45 MiB
# numpy      ------------------------------ 14.77 MiB/17.41 MiB
# lancedb    ------------------------------ 15.67 MiB/26.09 MiB
# pylance    ------------------------------ 16.83 MiB/29.11 MiB
# ⠇ Preparing packages... (218/223) 16.05 MiB/38.22 MiB
# pandas     ------------------------------ 9.67 MiB/12.45 MiB
# numpy      ------------------------------ 14.77 MiB/17.41 MiB
# lancedb    ------------------------------ 16.01 MiB/26.09 MiB
# pylance    ------------------------------ 17.97 MiB/29.11 MiB
# ⠋ Preparing packages... (218/223) 16.05 MiB/38.22 MiB
# pandas     ------------------------------ 9.67 MiB/12.45 MiB
# numpy      ------------------------------ 14.77 MiB/17.41 MiB
# lancedb    ------------------------------ 16.06 MiB/26.09 MiB
# pylance    ------------------------------ 18.00 MiB/29.11 MiB
# ⠋ Preparing packages... (218/223) 16.06 MiB/38.22 MiB
# pandas     ------------------------------ 9.67 MiB/12.45 MiB
# numpy      ------------------------------ 14.89 MiB/17.41 MiB
# lancedb    ------------------------------ 16.93 MiB/26.09 MiB
# pylance    ------------------------------ 18.94 MiB/29.11 MiB
# ⠋ Preparing packages... (218/223) 17.88 MiB/38.22 MiB
# pandas     ------------------------------ 9.75 MiB/12.45 MiB
# numpy      ------------------------------ 16.15 MiB/17.41 MiB
# lancedb    ------------------------------ 17.82 MiB/26.09 MiB
# pylance    ------------------------------ 20.31 MiB/29.11 MiB
# ⠋ Preparing packages... (218/223) 18.72 MiB/38.22 MiB
# pandas     ------------------------------ 10.31 MiB/12.45 MiB
# numpy      ------------------------------ 16.39 MiB/17.41 MiB
# lancedb    ------------------------------ 19.15 MiB/26.09 MiB
# pylance    ------------------------------ 21.61 MiB/29.11 MiB
# ⠙ Preparing packages... (218/223) 19.99 MiB/38.22 MiB
# pandas     ------------------------------ 10.89 MiB/12.45 MiB
# numpy      ------------------------------ 16.40 MiB/17.41 MiB
# lancedb    ------------------------------ 21.03 MiB/26.09 MiB
# pylance    ------------------------------ 23.31 MiB/29.11 MiB
# ⠙ Preparing packages... (218/223) 19.99 MiB/38.22 MiB
# pandas     ------------------------------ 10.89 MiB/12.45 MiB
# numpy      ------------------------------ 16.41 MiB/17.41 MiB
# lancedb    ------------------------------ 21.03 MiB/26.09 MiB
# pylance    ------------------------------ 23.31 MiB/29.11 MiB
# ⠙ Preparing packages... (218/223) 19.99 MiB/38.22 MiB
# pandas     ------------------------------ 10.89 MiB/12.45 MiB
# lancedb    ------------------------------ 21.03 MiB/26.09 MiB
# pylance    ------------------------------ 23.31 MiB/29.11 MiB
# ⠹ Preparing packages... (219/223) 19.99 MiB/38.22 MiB
# pandas     ------------------------------ 10.89 MiB/12.45 MiB
# lancedb    ------------------------------ 21.03 MiB/26.09 MiB
# pylance    ------------------------------ 23.31 MiB/29.11 MiB
# ⠹ Preparing packages... (219/223) 19.99 MiB/38.22 MiB
# pandas     ------------------------------ 10.89 MiB/12.45 MiB
# lancedb    ------------------------------ 21.03 MiB/26.09 MiB
# pylance    ------------------------------ 23.31 MiB/29.11 MiB
# ⠹ Preparing packages... (219/223) 20.08 MiB/38.22 MiB
# pandas     ------------------------------ 10.89 MiB/12.45 MiB
# lancedb    ------------------------------ 21.44 MiB/26.09 MiB
# pylance    ------------------------------ 23.31 MiB/29.11 MiB
# ⠹ Preparing packages... (219/223) 23.35 MiB/38.22 MiB
# pandas     ------------------------------ 10.89 MiB/12.45 MiB
# lancedb    ------------------------------ 21.55 MiB/26.09 MiB
# pylance    ------------------------------ 23.32 MiB/29.11 MiB
# ⠹ Preparing packages... (219/223) 24.06 MiB/38.22 MiB
# pandas     ------------------------------ 10.89 MiB/12.45 MiB
# lancedb    ------------------------------ 21.55 MiB/26.09 MiB
# pylance    ------------------------------ 23.33 MiB/29.11 MiB
# ⠹ Preparing packages... (219/223) 24.06 MiB/38.22 MiB
# pandas     ------------------------------ 10.89 MiB/12.45 MiB
# lancedb    ------------------------------ 21.55 MiB/26.09 MiB
# pylance    ------------------------------ 23.47 MiB/29.11 MiB
# ⠸ Preparing packages... (219/223) 24.06 MiB/38.22 MiB
# pandas     ------------------------------ 10.89 MiB/12.45 MiB
# lancedb    ------------------------------ 21.55 MiB/26.09 MiB
# pylance    ------------------------------ 23.50 MiB/29.11 MiB
# ⠼ Preparing packages... (219/223) 24.17 MiB/38.22 MiB
# pandas     ------------------------------ 10.89 MiB/12.45 MiB
# lancedb    ------------------------------ 21.55 MiB/26.09 MiB
# pylance    ------------------------------ 23.50 MiB/29.11 MiB
# ⠼ Preparing packages... (219/223) 24.91 MiB/38.22 MiB
# pandas     ------------------------------ 10.89 MiB/12.45 MiB
# lancedb    ------------------------------ 21.55 MiB/26.09 MiB
# pylance    ------------------------------ 23.57 MiB/29.11 MiB
# ⠼ Preparing packages... (219/223) 24.91 MiB/38.22 MiB
# pandas     ------------------------------ 10.89 MiB/12.45 MiB
# lancedb    ------------------------------ 21.55 MiB/26.09 MiB
# pylance    ------------------------------ 23.58 MiB/29.11 MiB
# ⠼ Preparing packages... (219/223) 24.91 MiB/38.22 MiB
# pandas     ------------------------------ 10.89 MiB/12.45 MiB
# lancedb    ------------------------------ 21.55 MiB/26.09 MiB
# pylance    ------------------------------ 23.59 MiB/29.11 MiB
# ⠼ Preparing packages... (219/223) 24.91 MiB/38.22 MiB
# pandas     ------------------------------ 10.89 MiB/12.45 MiB
# lancedb    ------------------------------ 21.55 MiB/26.09 MiB
# pylance    ------------------------------ 23.75 MiB/29.11 MiB
# ⠴ Preparing packages... (219/223) 24.91 MiB/38.22 MiB
# pandas     ------------------------------ 11.37 MiB/12.45 MiB
# lancedb    ------------------------------ 21.81 MiB/26.09 MiB
# pylance    ------------------------------ 23.75 MiB/29.11 MiB
# ⠴ Preparing packages... (219/223) 26.59 MiB/38.22 MiB
# pandas     ------------------------------ 11.37 MiB/12.45 MiB
# lancedb    ------------------------------ 21.81 MiB/26.09 MiB
# pylance    ------------------------------ 23.75 MiB/29.11 MiB
# ⠴ Preparing packages... (219/223) 26.63 MiB/38.22 MiB
# pandas     ------------------------------ 11.37 MiB/12.45 MiB
# lancedb    ------------------------------ 21.81 MiB/26.09 MiB
# pylance    ------------------------------ 23.75 MiB/29.11 MiB
# ⠴ Preparing packages... (219/223) 26.64 MiB/38.22 MiB
# pandas     ------------------------------ 11.37 MiB/12.45 MiB
# lancedb    ------------------------------ 21.81 MiB/26.09 MiB
# pylance    ------------------------------ 23.75 MiB/29.11 MiB
# ⠴ Preparing packages... (219/223) 28.26 MiB/38.22 MiB
# pandas     ------------------------------ 11.37 MiB/12.45 MiB
# lancedb    ------------------------------ 21.81 MiB/26.09 MiB
# pylance    ------------------------------ 23.75 MiB/29.11 MiB
# ⠦ Preparing packages... (219/223) 31.05 MiB/38.22 MiB
# pandas     ------------------------------ 11.70 MiB/12.45 MiB
# lancedb    ------------------------------ 21.81 MiB/26.09 MiB
# pylance    ------------------------------ 23.98 MiB/29.11 MiB
# ⠦ Preparing packages... (219/223) 31.38 MiB/38.22 MiB
# pandas     ------------------------------ 11.70 MiB/12.45 MiB
# lancedb    ------------------------------ 21.81 MiB/26.09 MiB
# pylance    ------------------------------ 24.07 MiB/29.11 MiB
# ⠦ Preparing packages... (219/223) 31.38 MiB/38.22 MiB
# pandas     ------------------------------ 11.70 MiB/12.45 MiB
# lancedb    ------------------------------ 21.81 MiB/26.09 MiB
# pylance    ------------------------------ 24.20 MiB/29.11 MiB
# ⠦ Preparing packages... (219/223) 31.38 MiB/38.22 MiB
# pandas     ------------------------------ 11.70 MiB/12.45 MiB
# lancedb    ------------------------------ 21.81 MiB/26.09 MiB
# pylance    ------------------------------ 26.23 MiB/29.11 MiB
# ⠧ Preparing packages... (219/223) 31.38 MiB/38.22 MiB
# pandas     ------------------------------ 11.70 MiB/12.45 MiB
# lancedb    ------------------------------ 21.81 MiB/26.09 MiB
# pylance    ------------------------------ 28.05 MiB/29.11 MiB
# ⠧ Preparing packages... (219/223) 31.38 MiB/38.22 MiB
# pandas     ------------------------------ 11.72 MiB/12.45 MiB
# lancedb    ------------------------------ 21.81 MiB/26.09 MiB
# pylance    ------------------------------ 28.05 MiB/29.11 MiB
# ⠧ Preparing packages... (219/223) 31.38 MiB/38.22 MiB
# pandas     ------------------------------ 11.73 MiB/12.45 MiB
# lancedb    ------------------------------ 21.81 MiB/26.09 MiB
# pylance    ------------------------------ 28.05 MiB/29.11 MiB
# ⠧ Preparing packages... (219/223) 31.38 MiB/38.22 MiB
# lancedb    ------------------------------ 21.81 MiB/26.09 MiB
# pylance    ------------------------------ 28.05 MiB/29.11 MiB
# ⠧ Preparing packages... (219/223) 31.38 MiB/38.22 MiB
# lancedb    ------------------------------ 21.81 MiB/26.09 MiB
# pylance    ------------------------------ 28.05 MiB/29.11 MiB
# ⠧ Preparing packages... (219/223) 31.40 MiB/38.22 MiB
# lancedb    ------------------------------ 21.81 MiB/26.09 MiB
# pylance    ------------------------------ 28.05 MiB/29.11 MiB
# ⠇ Preparing packages... (220/223) 34.64 MiB/38.22 MiB
# lancedb    ------------------------------ 21.81 MiB/26.09 MiB
# ⠇ Preparing packages... (220/223) 34.77 MiB/38.22 MiB
# lancedb    ------------------------------ 23.28 MiB/26.09 MiB
# ⠇ Preparing packages... (220/223) 36.40 MiB/38.22 MiB
# lancedb    ------------------------------ 24.78 MiB/26.09 MiB
# ⠇ Preparing packages... (220/223) 37.19 MiB/38.22 MiB
# lancedb    ------------------------------ 24.98 MiB/26.09 MiB
# ⠋ Preparing packages... (221/223) 37.51 MiB/38.22 MiB
# lancedb    ------------------------------ 25.36 MiB/26.09 MiB
# ⠋ Preparing packages... (221/223) 37.51 MiB/38.22 MiB
# lancedb    ------------------------------ 25.36 MiB/26.09 MiB
# ⠋ Preparing packages... (221/223) 37.54 MiB/38.22 MiB
# lancedb    ------------------------------ 25.36 MiB/26.09 MiB
# ⠋ Preparing packages... (221/223) 37.56 MiB/38.22 MiB
# ⠙ Preparing packages... (222/223) 25.36 MiB/26.09 MiB
# ⠙ Preparing packages... (222/223) 25.36 MiB/26.09 MiB
# Prepared 223 packages in 7.23s
# Installed 223 packages in 118ms
#  + aiohappyeyeballs==2.4.3
#  + aiohttp==3.11.8
#  + aiosignal==1.3.1
#  + alembic==1.14.0
#  + annotated-types==0.7.0
#  + anyio==4.6.2.post1
#  + appdirs==1.4.4
#  + asgiref==3.8.1
#  + asttokens==2.4.1
#  + attrs==24.2.0
#  + auth0-python==4.7.2
#  + backoff==2.2.1
#  + bcrypt==4.2.1
#  + beautifulsoup4==4.12.3
#  + build==1.2.2.post1
#  + cachetools==5.5.0
#  + certifi==2024.8.30
#  + cffi==1.17.1
#  + charset-normalizer==3.4.0
#  + chroma-hnswlib==0.7.6
#  + chromadb==0.5.20
#  + click==8.1.7
#  + cohere==5.12.0
#  + coloredlogs==15.0.1
#  + crewai==0.83.0
#  + crewai-tools==0.14.0
#  + cryptography==43.0.3
#  + dataclasses-json==0.6.7
#  + decorator==5.1.1
#  + deprecated==1.2.15
#  + deprecation==2.1.0
#  + distro==1.9.0
#  + docker==7.1.0
#  + docstring-parser==0.16
#  + docx2txt==0.8
#  + durationpy==0.9
#  + embedchain==0.1.125
#  + et-xmlfile==2.0.0
#  + executing==2.1.0
#  + fastapi==0.115.5
#  + fastavro==1.9.7
#  + filelock==3.16.1
#  + flatbuffers==24.3.25
#  + frozenlist==1.5.0
#  + fsspec==2024.10.0
#  + google-api-core==2.23.0
#  + google-auth==2.36.0
#  + google-cloud-aiplatform==1.73.0
#  + google-cloud-bigquery==3.27.0
#  + google-cloud-core==2.4.1
#  + google-cloud-resource-manager==1.13.1
#  + google-cloud-storage==2.18.2
#  + google-crc32c==1.6.0
#  + google-resumable-media==2.7.2
#  + googleapis-common-protos==1.66.0
#  + gptcache==0.1.44
#  + greenlet==3.1.1
#  + grpc-google-iam-v1==0.13.1
#  + grpcio==1.68.0
#  + grpcio-status==1.68.0
#  + grpcio-tools==1.68.0
#  + h11==0.14.0
#  + h2==4.1.0
#  + hpack==4.0.0
#  + httpcore==1.0.7
#  + httptools==0.6.4
#  + httpx==0.28.0
#  + httpx-sse==0.4.0
#  + huggingface-hub==0.26.3
#  + humanfriendly==10.0
#  + hyperframe==6.0.1
#  + idna==3.10
#  + importlib-metadata==8.5.0
#  + importlib-resources==6.4.5
#  + iniconfig==2.0.0
#  + instructor==1.7.0
#  + ipython==8.29.0
#  + jedi==0.19.2
#  + jinja2==3.1.4
#  + jiter==0.6.1
#  + json-repair==0.30.2
#  + jsonpatch==1.33
#  + jsonpickle==4.0.0
#  + jsonpointer==3.0.0
#  + jsonref==1.1.0
#  + jsonschema==4.23.0
#  + jsonschema-specifications==2024.10.1
#  + kubernetes==31.0.0
#  + lancedb==0.16.0
#  + langchain==0.3.9
#  + langchain-cohere==0.3.3
#  + langchain-community==0.3.4
#  + langchain-core==0.3.21
#  + langchain-experimental==0.3.3
#  + langchain-openai==0.2.10
#  + langchain-text-splitters==0.3.2
#  + langsmith==0.1.147
#  + litellm==1.53.1
#  + mako==1.3.6
#  + markdown-it-py==3.0.0
#  + markupsafe==3.0.2
#  + marshmallow==3.23.1
#  + matplotlib-inline==0.1.7
#  + mdurl==0.1.2
#  + mem0ai==0.1.34
#  + mmh3==5.0.1
#  + monotonic==1.6
#  + mpmath==1.3.0
#  + multidict==6.1.0
#  + mypy-extensions==1.0.0
#  + nest-asyncio==1.6.0
#  + networkx==3.4.2
#  + new-project==0.1.0 (from file:///home/jovyan/work/L13/new_project)
#  + nodeenv==1.9.1
#  + numpy==1.26.4
#  + oauthlib==3.2.2
#  + onnxruntime==1.20.1
#  + openai==1.55.3
#  + openpyxl==3.1.5
#  + opentelemetry-api==1.28.2
#  + opentelemetry-exporter-otlp-proto-common==1.28.2
#  + opentelemetry-exporter-otlp-proto-grpc==1.28.2
#  + opentelemetry-exporter-otlp-proto-http==1.28.2
#  + opentelemetry-instrumentation==0.49b2
#  + opentelemetry-instrumentation-asgi==0.49b2
#  + opentelemetry-instrumentation-fastapi==0.49b2
#  + opentelemetry-proto==1.28.2
#  + opentelemetry-sdk==1.28.2
#  + opentelemetry-semantic-conventions==0.49b2
#  + opentelemetry-util-http==0.49b2
#  + orjson==3.10.12
#  + outcome==1.3.0.post0
#  + overrides==7.7.0
#  + packaging==24.2
#  + pandas==2.2.3
#  + parameterized==0.9.0
#  + parso==0.8.4
#  + pdfminer-six==20231228
#  + pdfplumber==0.11.4
#  + pexpect==4.9.0
#  + pillow==11.0.0
#  + pluggy==1.5.0
#  + portalocker==2.10.1
#  + posthog==3.7.4
#  + prompt-toolkit==3.0.48
#  + propcache==0.2.0
#  + proto-plus==1.25.0
#  + protobuf==5.29.0
#  + ptyprocess==0.7.0
#  + pure-eval==0.2.3
#  + pyarrow==18.1.0
#  + pyasn1==0.6.1
#  + pyasn1-modules==0.4.1
#  + pycparser==2.22
#  + pydantic==2.10.2
#  + pydantic-core==2.27.1
#  + pydantic-settings==2.6.1
#  + pygments==2.18.0
#  + pyjwt==2.10.1
#  + pylance==0.19.2
#  + pypdf==5.1.0
#  + pypdfium2==4.30.0
#  + pypika==0.48.9
#  + pyproject-hooks==1.2.0
#  + pyright==1.1.389
#  + pysbd==0.3.4
#  + pysocks==1.7.1
#  + pytest==8.3.3
#  + python-dateutil==2.9.0.post0
#  + python-dotenv==1.0.1
#  + pytube==15.0.0
#  + pytz==2024.2
#  + pyvis==0.3.2
#  + pyyaml==6.0.2
#  + qdrant-client==1.12.1
#  + referencing==0.35.1
#  + regex==2024.11.6
#  + requests==2.32.3
#  + requests-oauthlib==2.0.0
#  + requests-toolbelt==1.0.0
#  + rich==13.9.4
#  + rpds-py==0.21.0
#  + rsa==4.9
#  + schema==0.7.7
#  + selenium==4.27.1
#  + setuptools==75.6.0
#  + shapely==2.0.6
#  + shellingham==1.5.4
#  + six==1.16.0
#  + sniffio==1.3.1
#  + sortedcontainers==2.4.0
#  + soupsieve==2.6
#  + sqlalchemy==2.0.36
#  + stack-data==0.6.3
#  + starlette==0.41.3
#  + sympy==1.13.3
#  + tabulate==0.9.0
#  + tenacity==9.0.0
#  + tiktoken==0.7.0
#  + tokenizers==0.21.0
#  + tomli==2.2.1
#  + tomli-w==1.1.0
#  + tqdm==4.67.1
#  + traitlets==5.14.3
#  + trio==0.27.0
#  + trio-websocket==0.11.1
#  + typer==0.13.1
#  + types-requests==2.32.0.20241016
#  + typing-extensions==4.12.2
#  + typing-inspect==0.9.0
#  + tzdata==2024.2
#  + urllib3==2.2.3
#  + uv==0.5.5
#  + uvicorn==0.32.1
#  + uvloop==0.21.0
#  + watchfiles==1.0.0
#  + wcwidth==0.2.13
#  + websocket-client==1.8.0
#  + websockets==14.1
#  + wrapt==1.17.0
#  + wsproto==1.2.0
#  + yarl==1.18.0
#  + zipp==3.21.0

# %% [markdown]
# ## Setting Environment Variables

# %%
! cat new_project/.env
# Out:
# OPENAI_API_KEY=YOUR_API_KEY_HERE

# %% [markdown]
# ## Running the Crew

# %%
! cd new_project && crewai run
# Out:
# Running the Crew
# # Agent: AI LLMs Senior Data Researcher
# ## Task: Conduct a thorough research about AI LLMs Make sure you find any interesting and relevant information given the current year is 2024.
#
#
#
# # Agent: AI LLMs Senior Data Researcher
# ## Final Answer:
# 1. **Multimodal Capabilities**: Recent advancements in AI LLMs, such as OpenAI's GPT-4 and Google's PaLM, showcase multimodal capabilities, allowing the models to process and generate text, images, and even audio, enhancing user interaction across numerous formats.
#
# 2. **Fine-tuning Techniques**: Researchers have introduced advanced fine-tuning methods, such as Reinforcement Learning from Human Feedback (RLHF) and low-shot learning, enabling LLMs to better align with human preferences and improve performance in specific applications.
#
# 3. **Efficiency and Scaling**: Innovative architectures like mixture of experts (MoE) are allowing LLMs to scale more efficiently, enabling them to maintain high performance levels while reducing the computational load, making training and deployment more accessible.
#
# 4. **Conversational Agents**: AI LLMs are now being utilized to create sophisticated conversational agents across industries, from customer service to mental health support, achieving more natural and contextually aware interactions.
#
# 5. **Ethical AI and Regulation**: Organizations are increasingly focusing on ethical considerations and regulatory measures related to AI LLMs, addressing issues like bias, accountability, and data privacy to ensure responsible AI deployment.
#
# 6. **Community-Driven Models**: The rise of open-source LLMs, such as EleutherAI's GPT-Neo and Meta's LLaMA, is fostering community engagement and democratizing AI research, allowing developers all over the world to innovate and collaborate on improvements.
#
# 7. **Task-Specific Models**: There is a growing trend in developing task-specific LLMs that are optimized for particular functions, such as CodeGen for programming or BioBERT for biomedical text, thus enhancing performance in niche areas.
#
# 8. **Integration with Other Technologies**: AI LLMs are being integrated with other AI technologies, such as computer vision and robotics, expanding their applicability in fields like autonomous driving and smart manufacturing.
#
# 9. **Improved Evaluation Metrics**: Researchers are developing more robust evaluation metrics for LLMs to better assess their performance and capabilities, focusing on aspects such as coherence, factual correctness, and contextual understanding.
#
# 10. **Collaborative Research Initiatives**: Major tech companies and academic institutions are forming collaborative initiatives to accelerate research in AI LLMs, focusing on practical applications, safety, and ethical considerations, thus establishing a more comprehensive understanding of impact and potential future directions.
#
#
# # Agent: AI LLMs Reporting Analyst
# ## Task: Review the context you got and expand each topic into a full section for a report. Make sure the report is detailed and contains any and all relevant information.
#
#
#
# # Agent: AI LLMs Reporting Analyst
# ## Final Answer:
# # Comprehensive Report on Recent Advancements in AI LLMs
#
# ## 1. Multimodal Capabilities
# Recent advancements in AI LLMs such as OpenAI's GPT-4 and Google's PaLM have introduced multimodal capabilities that allow these models to process and generate multiple forms of media including text, images, and audio. This expansion enhances user interactions by providing richer and more engaging experiences across various platforms. For instance, in educational settings, multimodal models can support learners by providing textual explanations alongside relevant images or audio clips, catering to diverse learning styles. Moreover, businesses can leverage these capabilities for marketing content, where an ad can automatically generate a corresponding image or a short audio clip, thus streamlining content creation processes.
#
# ## 2. Fine-tuning Techniques
# The development of fine-tuning techniques, particularly Reinforcement Learning from Human Feedback (RLHF) and low-shot learning, has significantly progressed the efficiency and effectiveness of LLMs. RLHF allows models to adjust their responses based on human feedback, promoting better alignment with user intentions and expectations. This technique helps create systems that are not only more accurate but also adapt to user preferences in real-time. Low-shot learning, on the other hand, enables models to perform tasks effectively with limited training data, which is especially useful in specialized domains where annotated data may be scarce. Collectively, these methods enhance the versatility of LLMs in responding to specific user needs.
#
# ## 3. Efficiency and Scaling
# Innovative architectures such as Mixture of Experts (MoE) have revolutionized the scalability of AI LLMs. This technique allows a network to dynamically select subsets of experts to handle queries, thereby maintaining high performance levels while minimizing computational resources. By distributing computational load more effectively, organizations can train larger models without the prohibitive costs typically associated with extensive data processing. This efficiency opens doors for broader deployment of high-performance LLMs across different sectors, making them more accessible to various industries and applications.
#
# ## 4. Conversational Agents
# AI LLMs have emerged as the backbone for creating sophisticated conversational agents, significantly transforming sectors such as customer service, healthcare, and education. These agents are designed to conduct natural and contextually aware conversations, usually indistinguishable from interactions with human representatives. In customer service, for example, LLMs can handle inquiries, troubleshoot problems, and guide users through complex processes. In mental health support, they can provide immediate assistance and guidance, enhancing the availability of resources while ensuring compassionate engagement.
#
# ## 5. Ethical AI and Regulation
# As the capabilities of AI LLMs expand, so too does the scrutiny surrounding their ethical implications and regulatory measures. Key concerns include addressing biases inherent in training data, establishing accountability in decision-making processes, and ensuring data privacy. Organizations are now implementing frameworks that prioritize responsible AI deployment, where transparency and fairness become central tenets. Regulatory measures are also developing, aiming to establish guidelines that prevent misuse while fostering innovation in a controlled manner.
#
# ## 6. Community-Driven Models
# The emergence of community-driven models has inspired a surge in open-source AI LLMs, exemplified by EleutherAI's GPT-Neo and Meta's LLaMA. This movement has democratized access to AI research and development, allowing developers and researchers from diverse backgrounds to contribute to and benefit from communal knowledge-sharing. With community engagement, continuous improvements and innovations come forth that otherwise may be constrained in proprietary environments. This collaboration fosters a vibrant ecosystem that propels the advancement of AI technologies.
#
# ## 7. Task-Specific Models
# A notable trend in AI LLM development is the creation of task-specific models optimized for particular domains, such as CodeGen for code generation or BioBERT tailored for biomedical text analysis. These specialized models deliver enhanced performance compared to general-purpose ones, providing solutions that are not only industry-relevant but also yield substantial improvements in accuracy and speed. As industries recognize the need for precision, this trend supports a growing demand for tailored LLMs that address niche areas effectively.
#
# ## 8. Integration with Other Technologies
# AI LLMs are increasingly being integrated with other technologies like computer vision and robotics, broadening their applicability across various fields, including autonomous driving and smart manufacturing. This convergence allows for richer interactions where LLMs can interpret visual data and provide contextual narratives, thus enhancing machine learning systems’ intelligence. In autonomous vehicles, for example, LLMs can assist in decision-making processes by interpreting sensory data and delivering real-time insights, paving the way for safer, more effective systems.
#
# ## 9. Improved Evaluation Metrics
# The need for improved evaluation metrics has led researchers to focus on developing more robust frameworks to assess LLMs comprehensively. Current metrics aim to evaluate aspects such as coherence, factual correctness, contextual understanding, and diversity of responses. By employing a more rigorous evaluation process, developers can identify the strengths and weaknesses of LLMs better, leading to informed improvements in their design and functionality. This focus on evaluation is essential for advancing the field and enhancing user confidence in AI systems.
#
# ## 10. Collaborative Research Initiatives
# Collaborative research initiatives are increasingly becoming a focal point for both major tech companies and academic institutions aiming to accelerate advancements in AI LLMs. These partnerships emphasize the importance of sharing knowledge and resources to focus on practical applications, safety concerns, and ethical implications. By pooling expertise, entities can establish a more comprehensive understanding of how to navigate the complexities of AI and its integration into society. Such collaborations also allow for more innovative solutions to arise and set the groundwork for future research directions.
#
# This report summarizes the latest developments within the domain of AI LLMs, providing an overview of the significant advancements and trends shaping the future of this technology. As the field continues to evolve, the collaboration between technology, ethics, and societal impact will play an essential role in determining the trajectory of AI development.

# %% [markdown]
# ## Flows CLI - Command Line Interface

# %%
! crewai create flow new_flow
# Out:
# Creating flow new_flow...
# Flow new_flow created successfully!

# %%
! ls -1 new_flow
# Out:
# README.md
# pyproject.toml
# src
# tests

# %%
! ls -1 new_flow/src/new_flow/
# Out:
# __init__.py
# crews
# main.py
# tools
